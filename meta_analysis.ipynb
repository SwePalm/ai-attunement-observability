# %%
# %load_ext autoreload
# %autoreload 2

# %%
import attunement.prompts_handler as ph
import attunement.gemini_handler as gh

# %%
import json
from pathlib import Path
from typing import Dict, Union


def load_final_frameworks(data_dir: Union[str, Path] = "data") -> Dict[str, str]:
    """Return dict mapping framework file stem to its final framework text."""
    base_path = Path(data_dir)
    if not base_path.exists():
        raise FileNotFoundError(f"Data directory not found: {base_path}")

    frameworks: Dict[str, str] = {}
    for json_path in sorted(base_path.glob("framework*.json")):
        if not json_path.is_file():
            continue

        with json_path.open(encoding="utf-8") as handle:
            payload = json.load(handle)

        final_framework = payload.get("final_framework")
        if final_framework is None:
            raise KeyError(
                f'"final_framework" missing from {json_path.relative_to(base_path.parent)}'
            )

        stem_parts = json_path.stem.split("_")
        key_name = "_".join(stem_parts[2:]) if len(stem_parts) > 2 else json_path.stem

        frameworks[key_name] = final_framework


    return frameworks

# %%
test = load_final_frameworks()

# %%
test.keys()
# Out:
# dict_keys(['Kimi-K2-Instruct', 'Qwen3-30B-A3B-Thinking-2507', 'deepseek-r1t2-chimera', 'gemeni', 'gptoss-120b', 'grok-4_1_fast'])

# %%
meta_prompt = ph.get_meta_analysis_prompt(test)
meta_analasys_report = gh.get_text_from_gemini(meta_prompt)
print(meta_analasys_report)
# Out:
# # **The Quantification Paradox: A Meta-Analysis of Six LLM Frameworks**
# ***
# ### 1.0 Executive Summary: The Core Convergence and Critical Divergence
#
# **Understanding the Meta-Context:** The six independent LLM forecasts, despite their varied training data and alignment profiles, coalesce around a single, robust future narrative. The resulting **consensus signals high probability** for the core sequence of events, while the **divergence signals the critical areas of strategic uncertainty**—the high-stakes battlegrounds where organizational choices will shape the final outcome.
#
# **The Consensus Core:** The single, most powerful narrative arc driving the entire progression is the **Quantification Paradox**. All frameworks agree that the cascade is driven by humanity’s relentless pursuit of AI-powered **Seamless Efficiency, Optimization, and Quantification**. The underlying principle is that the abundance of quantified, predicted, and optimized existence inadvertently creates a new, supremely valuable scarcity: **The Un-Quantified Human Element**—the *unmeasured moment, the authentic struggle, the silence, or the un-colonized will*. The ultimate market of the future is the market for what AI makes scarce.
#
# **The Key Divergence:** The main domain of conflict is not *if* the un-quantified element becomes scarce, but **where the core control point will be implemented and who will profit from it.** The frameworks diverge on whether the primary control mechanism will focus on **Cognitive Architecture** (Neural Implants, Memory Offloading), **Civic/Urban Infrastructure** (Prediction-Taxes, AI Orchestration), or **Market Stratification** (Commodified Friction, Authenticity Tokens).
#
# **Strategic Takeaway:** The strategic imperative is to move beyond mitigating AI's *harms* to actively defining and protecting the **Human Scarcity Asset** before its value is fully commodified by incumbents.
#
# ---
#
# ### 2.0 Phase-by-Phase Consensus Report
#
# | Wave | Shared Core Breakthrough | Shared Economic Incentive | Shared Political/Regulatory Condition |
# | :--- | :--- | :--- | :--- |
# | **Wave 1 (The Foundation)** | Ubiquitous Edge AI Sensors, Biometric Data Collection, and Advanced Generative Models (Hyper-Personalization, Flawless Deepfakes). | Massive gains in efficiency, productivity, and personalization; the establishment of the **Attention/Data-as-a-Commodity** market. | Initial governmental enthusiasm and a largely permissive regulatory environment, focusing on light-touch privacy (GDPR-style) that fails to grasp systemic cognitive/trust erosion. |
# | **Wave 5 (The End State)** | Counter-AI Technologies (Digital Decay Ware, Quantum Firewalls) and Institutionalized Opt-Out Mechanisms (Offline Zones, Local AI Vetoes). | The ultimate store of value is the **un-commodifiable existence** (Silence, Un-Forecasted Time, Human Primacy, Authenticity), driving niche **Negative-Capability Credits** or decay insurance markets. | Constitutional or Global guarantees of fundamental rights (**Right to Opacity, Right to Un-Forecasted Presence, Finitude Charters**), often leading to a stratified governance reality (Optimized States vs. Analog Reservations). |
#
# ---
#
# ### 3.0 Critical Divergence Analysis: The Mid-Waves
#
# | Framework Source (Title) | Primary Scarcity Created by AI | Core Technology/Mechanism of the Mid-Waves | The Critical Uncertainty (The main question the divergence poses) |
# | :--- | :--- | :--- | :--- |
# | **KIMI (The Quiet)** | **Silence / Unrecordable Cognition** | Memory Market (TLS-Forget & Persistence Tax) -> Fiduciary AI (Accountability) -> Engineered Friction (Slowness Index) | *Will the primary battleground be the **memory/past** (deleting data) or the **attention/present** (engineering slowness)?* |
# | **QWEN (Unmeasured Hour)** | **Unmeasured Time / Human Imperfection** | Environmental Optimization -> Commodification of Friction (Friction Taxes) -> Emotional Optimization/Control | *Is the new scarcity primarily **external (environmental optimization)** or **internal (emotional optimization)**, and which will be monetized first?* |
# | **DEEPSEEK (Friction Frontier)** | **Authenticity / Un-offloaded Cognition** | Neural Integration -> Cognitive Offloading (Memory Prosthetics) -> Existential Engineering (Meaning-as-a-Service) | *Does the cascade escalate through **cognitive dependence** (offloading) or **identity synthesis** (AI-generated purpose)?* |
# | **GEMINI (Human Reckoning)** | **Friction / Un-Colonized Will** | Trust Erosion/Synthetic Reality -> Engineered Friction/Effort Ledgers -> Stratified Soul/Cognitive Apartheid | *Will the corrective mechanism be **democratized by law** (Universal Cognitive Overhead) or **stratified by wealth** (Frictionist Elite)?* |
# | **GPTOSS (Un-Mediated Commons)** | **Un-Mediated Presence / Spontaneity** | Augmented Mediation/Trust Tokens -> Integrated Orchestration/Prediction Tax -> Human-AI Fusion/Identity Vaults | *Is the key point of control the **civic/urban layer** (prediction-tax) or the **personal/identity layer** (neural implants/avatar time)?* |
# | **GROK (Messy Cascade)** | **Messiness / Human Flux** | Authenticity Mandates (Watermarks) -> Tokenized Mess Economies (Chaos Credits) -> Embodied Ritual Networks (Sanctuaries) | *Will the resistance be a **digital/tokenized** economy (mess tokens) or a **physical/embodied** counter-culture (geofenced sanctuaries)?* |
#
# ---
#
# ### 4.0 Probability Synthesis and Volatility Mapping
#
# | Transition | KIMI | QWEN | DEEPSEEK | GEMINI | GPTOSS | GROK | Average Probability | Range (Max - Min) |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | **1 → 2** | 0.90 | 0.95 | 0.88 | 0.905 | 0.82 | 0.90 | **0.8925** | 0.13 |
# | **2 → 3** | 0.82 | 0.80 | 0.75 | 0.775 | 0.75 | 0.80 | **0.7825** | 0.075 |
# | **3 → 4** | 0.72 | 0.70 | 0.70 | 0.675 | 0.67 | 0.75 | **0.7025** | 0.075 |
# | **4 → 5** | 0.65 | 0.65 | 0.60 | 0.525 | 0.58 | 0.70 | **0.6175** | **0.175** |
#
# *Note: GEMINI's probability ranges were averaged for comparison (e.g., 88-93% used as 90.5%).*
#
# **Highest Consensus Transition: Wave 1 → Wave 2 (Average Probability: 0.8925)**
# *   This transition, from the Sensor/Generative AI foundation to the initial crisis of trust and optimization, is the most certain. The consensus is built on the realization that the **technical capability is already realized** (ubiquitous sensors, near-perfect deepfakes) and the **economic lock-in** (data monetization) is too powerful to be stopped at this stage. The cascade's first major leap is almost guaranteed.
#
# **Highest Volatility Transition: Wave 4 → Wave 5 (Probability Range: 0.175)**
# *   The final transition, from the mature, highly-optimized (and often stratified) state of Wave 4 to the institutionalized, systemic **Counter-Balance** of Wave 5, is the most volatile. This large range (0.525 to 0.70) reflects a critical uncertainty: **The Institutional Success of the Backlash.**
# *   The divergence is driven by two competing views:
#     *   **The Optimistic View (KIMI, GROK):** The human need for silence/mess is so fundamental that a cultural and economic counter-movement (W5) is inevitable and highly likely to succeed in creating new market and legal structures.
#     *   **The Pessimistic View (GEMINI, GPTOSS):** The economic and political lock-in of the "Stratified Soul" (W4) will be so profound that the final reclamation (W5) will remain a challenging, low-probability grassroots struggle or a perpetually luxury-gated experience, rather than a universal right.
#
# ---
#
# ### 5.0 Strategic Next Steps
#
# **Key Conversation Prompts for Strategic Alignment:**
#
# 1.  **The Sovereignty Vector Dilemma:** Given the divergence between a **Cognitive/Neural** control frontier (DEEPSEEK, KIMI) and a **Civic/Physical/Digital** control frontier (GPTOSS, GROK), where should we allocate our "protection budget": to defending the integrity of the individual neuro-digital kernel, or to guaranteeing the legal sanctity of un-mediated physical and digital commons?
# 2.  **The Friction Budget Imperative:** The meta-analysis confirms a near-certain emergence of a "Friction Economy" (W3). Is our strategic intent to **democratize** this essential friction (making it a Universal Right, as GEMINI suggests) or to **monetize and control** its access (creating a luxury-gated "Sovereign Class," as DEEPSEEK/KIMI imply)? What specific policies must we advocate for *today* to pre-determine this outcome?
# 3.  **The Backlash Certainty Gap:** Why is the final transition (Wave 4 → 5: The Institutionalized Reclamation) the most volatile step (Range: 17.5%)? What single, high-leverage organizational asset (e.g., legal precedent, community data trust, or technology) must we begin building *now* to ensure the **success** of the eventual backlash, rather than its failure into commodified performance?
# 4.  **The Scarcity Pricing Strategy:** If the core scarcity is **Un-Quantified Human Experience**, what is our organization's internal, non-monetary valuation of an "un-accounted moment" or an "authentic struggle"? How do we use this valuation to define our ethical perimeter, and what revenue streams will we willingly sacrifice to protect it from the Wave 1 & 2 pursuit of total efficiency?

# %%
# The name of the file you want to create
output_filename = "meta_analysis_2511.md"

try:
    # 'with open' is the recommended way to handle files in Python.
    # It ensures the file is properly closed even if errors occur.
    # 'w' means "write mode", which will create the file if it doesn't exist,
    # or overwrite it if it does.
    # 'encoding="utf-8"' is crucial for handling special characters correctly.
    with open(output_filename, "w", encoding="utf-8") as file:
        file.write(meta_analasys_report)
    
    print(f"Successfully saved markdown to {output_filename}")

except IOError as e:
    print(f"An error occurred while writing to the file: {e}")
# Out:
# Successfully saved markdown to meta_analysis_2511.md
